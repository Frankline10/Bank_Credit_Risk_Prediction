# %% [markdown]
# # Phase 1 :- Data Understanding and Initial Exploration

# %%
# Importing Libraries


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
# Loading all datasets

account_df = pd.read_csv('/Users/soujanyaprokashsingha/Documents/Data Analyst_Science/Professional Projects/Datamites Projects/Bank_Credit_Risk_Prediction/data/raw/Cust_Account.csv')

enquiry_df = pd.read_csv('/Users/soujanyaprokashsingha/Documents/Data Analyst_Science/Professional Projects/Datamites Projects/Bank_Credit_Risk_Prediction/data/raw/Cust_Enquiry.csv')

demo_df = pd.read_csv('/Users/soujanyaprokashsingha/Documents/Data Analyst_Science/Professional Projects/Datamites Projects/Bank_Credit_Risk_Prediction/data/raw/Cust_Demographics.csv')

# %%
account_df.head()
# Out:
#    dt_opened  customer_no  upload_dt  acct_type  owner_indic  opened_dt  \
# 0  10-Nov-15        12265  20-Oct-15          6            1  09-Jun-13
# 1  10-Nov-15        12265  20-Oct-15         10            1  25-May-12
# 2  10-Nov-15        12265  20-Oct-15         10            1  22-Mar-12
# 3  20-Jul-15        15606  09-Jul-15         10            1  13-Jan-06
# 4  20-Jul-15        15606  09-Jul-15          6            1  18-Jan-15
#
#   last_paymt_dt  closed_dt reporting_dt  high_credit_amt  cur_balance_amt  \
# 0     30-Jun-14  05-Jul-14    30-Sep-15          20900.0                0
# 1     06-Sep-15        NaN    03-Oct-15          16201.0            10390
# 2     31-Aug-15        NaN    30-Sep-15          41028.0            34420
# 3           NaN  26-Jul-07    31-Jan-09          93473.0                0
# 4     05-May-15        NaN    31-May-15          20250.0            13500
#
#    amt_past_due                                    paymenthistory1  \
# ...

# %%
enquiry_df.head()
# Out:
#    dt_opened  customer_no  upload_dt enquiry_dt  enq_purpose    enq_amt
# 0  18-Apr-15            1  21-Apr-15  19-Dec-14          2.0  3500000.0
# 1  18-Apr-15            1  21-Apr-15  05-Mar-14          5.0   500000.0
# 2  18-Apr-15            1  21-Apr-15  05-Mar-14          0.0    50000.0
# 3  18-Apr-15            1  21-Apr-15  22-Feb-14         10.0    50000.0
# 4  18-Apr-15            1  21-Apr-15  11-Jun-13         10.0     1000.0

# %%
demo_df.head()
# Out:
#    dt_opened  customer_no entry_time feature_1  feature_2  feature_3  \
# 0  18-Apr-15            1  13-Apr-15  Insignia  13-Apr-15      650.0
# 1  21-Apr-15            2  21-Apr-15  Insignia  21-Apr-15      760.0
# 2  22-Apr-15            3  21-Apr-15  Insignia  21-Apr-15      774.0
# 3  25-Apr-15            4  15-Apr-15  Insignia  20-Apr-15      770.0
# 4  06-May-15            5  30-Apr-15  Insignia        NaN        NaN
#
#    feature_4   feature_5  feature_6  feature_7 feature_8 feature_9  \
# 0          2  Card Setup         14     500000       NaN       NaN
# 1          1  Card Setup         14    1200000       NaN       NaN
# 2          1  Card Setup         14     700000       NaN       NaN
# 3          1  Card Setup         14     500000       NaN       NaN
# 4          3  Card Setup         14     500000       NaN       NaN
#
#    feature_10 feature_11 feature_12 feature_13  feature_14 feature_15  \
# 0         NaN          Y        IS1        NaN         0.0        159
# ...

# %%
# Dataset shapes

print(account_df.shape)
print(enquiry_df.shape)
print(demo_df.shape)
# Out:
# (1000, 21)
# (1000, 6)
# (1000, 83)

# %%
# Checking Column names / feature names for each dataset

account_df.columns
# Out:
# Index(['dt_opened', 'customer_no', 'upload_dt', 'acct_type', 'owner_indic',
#        'opened_dt', 'last_paymt_dt', 'closed_dt', 'reporting_dt',
#        'high_credit_amt', 'cur_balance_amt', 'amt_past_due', 'paymenthistory1',
#        'paymenthistory2', 'paymt_str_dt', 'paymt_end_dt', 'creditlimit',
#        'cashlimit', 'rateofinterest', 'paymentfrequency',
#        'actualpaymentamount'],
#       dtype='str')

# %%
enquiry_df.columns
# Out:
# Index(['dt_opened', 'customer_no', 'upload_dt', 'enquiry_dt', 'enq_purpose',
#        'enq_amt'],
#       dtype='str')

# %%
demo_df.columns
# Out:
# Index(['dt_opened', 'customer_no', 'entry_time', 'feature_1', 'feature_2',
#        'feature_3', 'feature_4', 'feature_5', 'feature_6', 'feature_7',
#        'feature_8', 'feature_9', 'feature_10', 'feature_11', 'feature_12',
#        'feature_13', 'feature_14', 'feature_15', 'feature_16', 'feature_17',
#        'feature_18', 'feature_19', 'feature_20', 'feature_21', 'feature_22',
#        'feature_23', 'feature_24', 'feature_25', 'feature_26', 'feature_27',
#        'feature_28', 'feature_29', 'feature_30', 'feature_31', 'feature_32',
#        'feature_33', 'feature_34', 'feature_35', 'feature_36', 'feature_37',
#        'feature_38', 'feature_39', 'feature_40', 'feature_41', 'feature_42',
#        'feature_43', 'feature_44', 'feature_45', 'feature_46', 'feature_47',
#        'feature_48', 'feature_49', 'feature_50', 'feature_51', 'feature_52',
#        'feature_53', 'feature_54', 'feature_55', 'feature_56', 'feature_57',
# ...

# %%
# Checking dataset information for each dataset

account_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dt_opened            1000 non-null   str
#  1   customer_no          1000 non-null   int64
#  2   upload_dt            1000 non-null   str
#  3   acct_type            1000 non-null   int64
#  4   owner_indic          1000 non-null   int64
#  5   opened_dt            998 non-null    str
#  6   last_paymt_dt        863 non-null    str
#  7   closed_dt            445 non-null    str
#  8   reporting_dt         1000 non-null   str
#  9   high_credit_amt      927 non-null    float64
#  10  cur_balance_amt      1000 non-null   int64
#  11  amt_past_due         5 non-null      float64
#  12  paymenthistory1      1000 non-null   str
#  13  paymenthistory2      443 non-null    str
#  14  paymt_str_dt         1000 non-null   str
#  15  paymt_end_dt         1000 non-null   str
# ...

# %%
enquiry_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   dt_opened    1000 non-null   str
#  1   customer_no  1000 non-null   int64
#  2   upload_dt    999 non-null    str
#  3   enquiry_dt   999 non-null    str
#  4   enq_purpose  999 non-null    float64
#  5   enq_amt      999 non-null    float64
# dtypes: float64(2), int64(1), str(3)
# memory usage: 47.0 KB

# %%
demo_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 83 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   dt_opened    1000 non-null   str
#  1   customer_no  1000 non-null   int64
#  2   entry_time   1000 non-null   str
#  3   feature_1    1000 non-null   str
#  4   feature_2    903 non-null    str
#  5   feature_3    903 non-null    float64
#  6   feature_4    1000 non-null   int64
#  7   feature_5    1000 non-null   str
#  8   feature_6    1000 non-null   int64
#  9   feature_7    1000 non-null   int64
#  10  feature_8    3 non-null      str
#  11  feature_9    3 non-null      str
#  12  feature_10   0 non-null      float64
#  13  feature_11   1000 non-null   str
#  14  feature_12   1000 non-null   str
#  15  feature_13   728 non-null    str
#  16  feature_14   992 non-null    float64
#  17  feature_15   999 non-null    str
#  18  feature_16   998 non-null    str
# ...

# %%
# Dataset summary

account_df.describe()
# Out:
#         customer_no    acct_type  owner_indic  high_credit_amt  \
# count   1000.000000  1000.000000  1000.000000     9.270000e+02
# mean   11029.205000     8.185000     1.100000     1.932247e+05
# std     6588.250126     4.955132     0.519875     6.169454e+05
# min      109.000000     0.000000     1.000000     1.120000e+02
# 25%     5351.000000     6.000000     1.000000     2.304400e+04
# 50%    11828.000000    10.000000     1.000000     4.694200e+04
# 75%    16656.000000    10.000000     1.000000     1.328265e+05
# max    23739.000000    56.000000     4.000000     1.150000e+07
#
#        cur_balance_amt  amt_past_due    creditlimit      cashlimit  \
# count     1.000000e+03      5.000000     237.000000     179.000000
# mean      8.406128e+04  11597.200000   89449.789030   24359.329609
# std       4.852610e+05  19619.944513   84435.470484   29425.783120
# min      -1.234800e+04     17.000000    1500.000000       1.000000
# ...

# %%
enquiry_df.describe()
# Out:
#        customer_no  enq_purpose       enq_amt
# count  1000.000000   999.000000  9.990000e+02
# mean     28.000000    12.050050  2.293140e+07
# std      17.333102    17.101298  8.714317e+07
# min       1.000000     0.000000  1.000000e+00
# 25%      12.000000     1.000000  1.750000e+04
# 50%      28.000000     5.000000  2.600000e+05
# 75%      45.000000    10.000000  3.825000e+06
# max      51.000000    57.000000  8.000000e+08

# %%
demo_df.describe()
# Out:
#        customer_no   feature_3    feature_4  feature_6     feature_7  \
# count  1000.000000  903.000000  1000.000000     1000.0  1.000000e+03
# mean    500.500000  726.311185     2.661000       14.0  1.445281e+05
# std     288.819436   53.909503     0.683041        0.0  1.295870e+05
# min       1.000000   -1.000000     1.000000       14.0  8.100000e+03
# 25%     250.750000  700.000000     3.000000       14.0  7.500000e+04
# 50%     500.500000  725.000000     3.000000       14.0  1.130000e+05
# 75%     750.250000  753.000000     3.000000       14.0  1.600000e+05
# max    1000.000000  881.000000     3.000000       14.0  1.200000e+06
#
#        feature_10  feature_14  feature_18   feature_19  feature_25  \
# count         0.0  992.000000    3.000000  1000.000000  1000.00000
# mean          NaN    8.806452  150.333333     1.054000     1.19300
# std           NaN    5.305865   51.384174     0.226131     0.39485
# min           NaN    0.000000   91.000000     1.000000     1.00000
# ...

# %%
# Checking the missing values for each datasets

account_df.isnull().sum()
# Out:
# dt_opened                0
# customer_no              0
# upload_dt                0
# acct_type                0
# owner_indic              0
# opened_dt                2
# last_paymt_dt          137
# closed_dt              555
# reporting_dt             0
# high_credit_amt         73
# cur_balance_amt          0
# amt_past_due           995
# paymenthistory1          0
# paymenthistory2        557
# paymt_str_dt             0
# paymt_end_dt             0
# creditlimit            763
# cashlimit              821
# rateofinterest         882
# paymentfrequency       674
# actualpaymentamount    802
# dtype: int64

# %%
enquiry_df.isnull().sum()
# Out:
# dt_opened      0
# customer_no    0
# upload_dt      1
# enquiry_dt     1
# enq_purpose    1
# enq_amt        1
# dtype: int64

# %%
demo_df.isnull().sum()
# Out:
# dt_opened       0
# customer_no     0
# entry_time      0
# feature_1       0
# feature_2      97
#                ..
# feature_76      0
# feature_77      0
# feature_78      0
# feature_79      0
# Bad_label       0
# Length: 83, dtype: int64

# %%
# Calculating missing percentage for all datasets

(account_df.isnull().sum()/len(account_df))*100
# Out:
# dt_opened               0.0
# customer_no             0.0
# upload_dt               0.0
# acct_type               0.0
# owner_indic             0.0
# opened_dt               0.2
# last_paymt_dt          13.7
# closed_dt              55.5
# reporting_dt            0.0
# high_credit_amt         7.3
# cur_balance_amt         0.0
# amt_past_due           99.5
# paymenthistory1         0.0
# paymenthistory2        55.7
# paymt_str_dt            0.0
# paymt_end_dt            0.0
# creditlimit            76.3
# cashlimit              82.1
# rateofinterest         88.2
# paymentfrequency       67.4
# actualpaymentamount    80.2
# dtype: float64

# %%
(enquiry_df.isnull().sum()/len(enquiry_df))*100
# Out:
# dt_opened      0.0
# customer_no    0.0
# upload_dt      0.1
# enquiry_dt     0.1
# enq_purpose    0.1
# enq_amt        0.1
# dtype: float64

# %%
(demo_df.isnull().sum()/len(demo_df))*100
# Out:
# dt_opened      0.0
# customer_no    0.0
# entry_time     0.0
# feature_1      0.0
# feature_2      9.7
#               ...
# feature_76     0.0
# feature_77     0.0
# feature_78     0.0
# feature_79     0.0
# Bad_label      0.0
# Length: 83, dtype: float64

# %%
# Checking duplicate rows in each dataset

account_df.duplicated().sum()
# Out:
# np.int64(5)

# %%
enquiry_df.duplicated().sum()
# Out:
# np.int64(40)

# %%
demo_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Checking unique customers

account_df['customer_no'].nunique()
# Out:
# 123

# %%
enquiry_df['customer_no'].nunique()
# Out:
# 51

# %%
demo_df['customer_no'].nunique()
# Out:
# 1000

# %%
# Target Variable understanding

demo_df['Bad_label'].value_counts()
# Out:
# Bad_label
# 0    967
# 1     33
# Name: count, dtype: int64

# %%
# Visualization

sns.countplot(x='Bad_label', data=demo_df)
plt.show()

# %%
# Customer risk ratio

demo_df['Bad_label'].value_counts(normalize=True)*100
# Out:
# Bad_label
# 0    96.7
# 1     3.3
# Name: proportion, dtype: float64
